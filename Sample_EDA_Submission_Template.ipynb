# %% [markdown]
# # **Project Name**    -
# # **EDA_Airbnb**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Team
# ##### **Team Name** - phoenix
# ##### **Team Member 1 -** Umakant Mahanti
# ##### **Team Member 2 -** Samadhan Tangde

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/1002Sam/EDA_Airbnb.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Using Data Analysis, find out the most demanded room type, neighbourhood, occasion and destinations where most likely booking may happen. Focus should be on specific demography(age group) as well as geography(country of origin) for maximum lead generation (booking) through insightful and mathematical nuance. Prime target recommendation should be such Users and Interfaces like Web Browsers, ios app from where maximum booking happens.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# *   Recommending marketing campaign strategies and predicting the destinations where booking going to happen.
# *   Through data insights provide customers best experience for their expectations.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Importing Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Loading Dataset

from google.colab import drive
drive.mount('/content/drive')

file_path = '/content/drive/MyDrive/AlmaBetter /Python /EDA_Project /Airbnb NYC 2019.csv'
airbnb_df=pd.read_csv(file_path)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Basic Information about the Dataset

airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Duplicate Value Count in Dataset

airbnb_df.duplicated().sum()
airbnb_df.drop_duplicates(inplace=True)
airbnb_df.shape
# Out:
# (48895, 16)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

missing_values = airbnb_df.isnull().sum()
missing_values
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# The missing values table shows that there are 4 columns containing null values which are name, host_name (Thought that listing 'name and host_name' doesn't really matter beacuse it might have similar entries with different ids) and last_reviews, reviews_per_month (obviously, if a listing has never received a review, its possible and valid). So we will just fillna(0) to those null values

# %%
# Visualizing the missing values
#airbnb_df.fillna(0, inplace=True)

#use graph of columns on x axis and missing values on y axis
#Creating Bar Plot to Visualize Missing Values

columns = airbnb_df.columns
columns
#missing_values = total index - present values

plt.bar(missing_values, columns, color ='blue', width = 1.0)
plt.xlabel("columns")
plt.ylabel("missing_values")
plt.title("Visualization of Missing Values")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# We can see our dataset has 48895 data and 16 columns. Lets try to understand about the columns we've got here.
# *   id : a unique id identifying an airbnb lisitng
# *   name : name representing the accommodation
# *   host_id : a unique id identifying an airbnb host
# *  host_name : name under whom host is registered
# *   neighbourhood_group : a group of area
# *   neighbourhood : area falls under neighbourhood_group
# *   latitude : coordinate of listing
# *   longitude : coordinate of listing
# *   room_type : type to categorize listing rooms
# *   price : price of listing
# *   minimum_nights : the minimum nights required to stay in a single visit
# *   number_of_reviews : total count of reviews given by visitors
# *   last_review : date of last review given
# *   reviews_per_month : rate of reviews given per month
# *   calculated_host_listings_count : total no of listing registered under the host
# *   availability_365 : the number of days for which a host is available in a year.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

# Skimming through all the columns or say knowing given variables

airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Describing dataset with continuous variables
# We are excluding latitude & longitude as they are coordinates and id & host_id as they're unique, on unique values statistical operations would not give any insight. 
col_after_excluding = set(airbnb_df.columns) - {'latitude', 'longitude', 'id', 'host_id'}
airbnb_df[col_after_excluding].describe()
# Out:
#               price  number_of_reviews  minimum_nights  availability_365  \
# count  48895.000000       48895.000000    48895.000000      48895.000000
# mean     152.720687          23.274466        7.029962        112.781327
# std      240.154170          44.550582       20.510550        131.622289
# min        0.000000           0.000000        1.000000          0.000000
# 25%       69.000000           1.000000        1.000000          0.000000
# 50%      106.000000           5.000000        3.000000         45.000000
# 75%      175.000000          24.000000        5.000000        227.000000
# max    10000.000000         629.000000     1250.000000        365.000000
#
#        calculated_host_listings_count  reviews_per_month
# count                    48895.000000       38843.000000
# mean                         7.143982           1.373221
# std                         32.952519           1.680442
# min                          1.000000           0.010000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# So, we get to know that some columns falls under categorical and remaining are numeriacal except one last_review comes under Date_Time category.
# *   Categorical variable : name, host_name, neighbourhood_group,
#        neighbourhood, room_type
# *   Numerical variable : id, host_id, price,
#        minimum_nights, number_of_reviews, reviews_per_month, calculated_host_listings_count, availability_365
# *   Date_Time variable : last_review
# *  Coordinates : latitude, longitude

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

airbnb_df['host_name'].unique()
airbnb_df.host_name.nunique()
# Out:
# 11452

# %%
(airbnb_df['neighbourhood_group'].unique())
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
airbnb_df['neighbourhood'].nunique()
# Out:
# 221

# %%
airbnb_df["room_type"].value_counts()
# Out:
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: room_type, dtype: int64

# %%
price_value_counts = airbnb_df["price"].value_counts()

price_value_counts.sort_index()
# Out:
# 0        11
# 10       17
# 11        3
# 12        4
# 13        1
#          ..
# 7703      1
# 8000      1
# 8500      1
# 9999      3
# 10000     3
# Name: price, Length: 674, dtype: int64

# %%
airbnb_df["calculated_host_listings_count"].unique()
# Out:
# array([  6,   2,   1,   4,   3,   5,   7,  13,  28,  11,   8,   9,  52,
#         18,  15,  19,  10,  39,  26,  29,  12,  21,  96,  14,  34,  43,
#        121,  37,  49,  31,  91,  16,  87,  33,  23,  50,  20,  25, 232,
#         17,  47, 103,  65,  30,  27, 327,  32])

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# droping unnecessary columns

airbnb_df.drop(['name','id','host_name','last_review',], axis=1, inplace=True)

# %%
# Examining changes after droping unnecessary columns

airbnb_df.head()
# Out:
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1     2845           Manhattan       Midtown  40.75362  -73.98377
# 2     4632           Manhattan        Harlem  40.80902  -73.94190
# 3     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
#We know that reviews_per_month column have many null values, we will replace it with '0'.
airbnb_df.fillna({'reviews_per_month':0}, inplace=True)

# again examining changes
airbnb_df.reviews_per_month.isnull().sum()
# Out:
# 0

# %%
airbnb_df.head()
# Out:
#    host_id neighbourhood_group neighbourhood  latitude  longitude  \
# 0     2787            Brooklyn    Kensington  40.64749  -73.97237
# 1     2845           Manhattan       Midtown  40.75362  -73.98377
# 2     4632           Manhattan        Harlem  40.80902  -73.94190
# 3     4869            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4     7192           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    149               1                  9
# 1  Entire home/apt    225               1                 45
# 2     Private room    150               3                  0
# 3  Entire home/apt     89               1                270
# 4  Entire home/apt     80              10                  9
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# ...

# %%
airbnb_df.loc[:,['availability_365']] == '0'
# Out:
#        availability_365
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 48890             False
# 48891             False
# 48892             False
# 48893             False
# 48894             False
#
# [48895 rows x 1 columns]

# %%
hosts_listings = airbnb_df.groupby(['host_name','neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
hosts_listings.sort_values(by='calculated_host_listings_count', ascending=False).head(10)
# Out:
#                host_name neighbourhood_group  calculated_host_listings_count
# 13217       Sonder (NYC)           Manhattan                             327
# 1834          Blueground           Manhattan                             232
# 1833          Blueground            Brooklyn                             232
# 7275                Kara           Manhattan                             121
# 7480              Kazuya              Queens                             103
# 7479              Kazuya           Manhattan                             103
# 7478              Kazuya            Brooklyn                             103
# 13216             Sonder           Manhattan                              96
# 6540      Jeremy & Laura           Manhattan                              96
# 2901   Corporate Housing           Manhattan                              91

# %%
index_names = airbnb_df[(airbnb_df["price"] <= 0) | airbnb_df["availability_365"] == 0].index
index_names.value_counts
#airbnb_df.drop(index_names, inplace = True)
# Out:
# <bound method IndexOpsMixin.value_counts of Int64Index([    4,     6,     8,    14,    20,    26,    48,    66,    88,
#                94,
#             ...
#             48205, 48264, 48346, 48431, 48450, 48550, 48731, 48756, 48760,
#             48779],
#            dtype='int64', length=17530)>

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **From the above experiments we get some more insights like :**
# *   Entire home/apt have highest listings followed by Private room and Shared room have miniscule conteibution.
# *   Unique host_name number shows that one host have many roomtype and/or more than one listing in same and/or different neighbourhood.
# *   Overall listing has distibuted in 5 neighbourhood_group which are having over 200 neighbourhoods. Its price goes upto 10k.
# *   After inspection I figured out that a particular property name have one particular host_name hosted by that same individual but a particular host_name can have multiple properties in a neighbourhood_group or neighbourhood.
# *   From the info() we get to know that all the property ids are different and each listings are different here.
# *   By experimenting we get to know that in columns "price and availability_365" shows zero cost and not available throughout year respectively.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code

no_of_bookings = airbnb_df
chart1 = sns.countplot(data = no_of_bookings, x= "neighbourhood",palette='Set1')
chart1.set_xticklabels(chart1.get_xticklabels(), rotation=90)
fig = plt.gcf()
fig.set_size_inches(25,10)
plt.title("neighbourhood", fontsize = 20)
# Out:
# Text(0.5, 1.0, 'neighbourhood')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows the which neighbourhood had most no of booking.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Williamsburg ,Bedford-Stuyvesant and Harlem are top 3 neighbouhood which has most no of booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# With the help of this data we can find target places to improve services at those and it will also help to get profit by limiting the advertisement market area so we can minimize the cost and increase the profit.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

avg_price = airbnb_df.groupby(["neighbourhood_group"])["price"].mean()
a = avg_price.plot.bar(figsize = (10,5), fontsize = 14)
a.set_xlabel("neighbourhood_group", fontsize = 15)
a.set_ylabel("average price", fontsize = 15)
a.set_title("average house price for different places")
# Out:
# Text(0.5, 1.0, 'average house price for different places')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows price difference between the neighbourhood groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that Manhattan has the most average price in the neighbourhood group. This shows the demand for the Manhatten over others.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The higher average price shows more listing price can be feasible for making more profit as well as more listings can be done in the high demand neighboourhood. And spend on offline advertising accordingly.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

no_of_booking_neighbourhood_group = airbnb_df["neighbourhood_group"].value_counts()
no_of_booking_neighbourhood_group.plot.pie(autopct='%1.2f%%', ylabel = "",figsize=(10,10))
plt.title('no_of_booking_neighbourhood_group', fontsize = 18)
# Out:
# Text(0.5, 1.0, 'no_of_booking_neighbourhood_group')

# %%
airbnb_df['neighbourhood_group'].value_counts().plot(kind='bar',color=['r','b','y','g','m'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows the percentages of booking done in different neighbourhood group hence gets information of which Neighbourhood group has most of the bookings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows that only Manhattan and Brooklyn have more than 85% of orders. This way we can list more properties by targetting particular Neighbourhood group at the begining.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The gained insights will help to increase business by targeting particular area of market which have higher number of orders and booking. Keep track of no of listings in the area, keep eye on percentage occupancy to make sure the demand and supply doesn't mismatch.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code for finding most demanded room type

most_damand_room = airbnb_df.groupby(['room_type'])["host_id"].count()
b = most_damand_room.plot.bar(figsize = (10,5), fontsize = 14)
b.set_xlabel("room type", fontsize = 15)
b.set_ylabel("no of booking", fontsize = 15)
b.set_title("most demanded room type", fontsize=18)
# Out:
# Text(0.5, 1.0, 'most demanded room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows that which room type is in most demand.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From this chart we found that shared room is least in demand and most demand room type is entire house/apt, people like to rent a entire house/apt followed by shared room. So data suggests to make sure availability and service of demanded room type.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# It help us to know that most people want entire house/apt for rent so that according to our data we will try to make/list most no. of rental properties as entire house/apt or private rooms.

# %% [markdown]
# #### Chart - 5

# %%
from seaborn.widgets import choose_colorbrewer_palette
# Chart - 5 visualization code

# Chart - 5 this time we will try to find out average prices of different room types
new = airbnb_df.groupby(["room_type"])["price"].mean()
chart5 = new.plot.bar(figsize = (10,5), fontsize = 14)
chart5.set_xlabel("room type", fontsize = 16)
chart5.set_ylabel("average price", fontsize = 16)
chart5.set_title("average price in different room type", fontsize = 18)
# Out:
# Text(0.5, 1.0, 'average price in different room type')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the idea of average price of room type wrt their demand/occupancy  as showed in earlier one chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This Chart shows shows the average mean price of Entire home/apt is higher as compared to remaining two room types. This also give us profit oriented new listing approach for all stakeholders benefits.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# This Chart attracts special attention to make sure the avalability as well as best service for this room type for overall positive customer sentiments and good reviews.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

airbnb_df.groupby('room_type')['minimum_nights'].mean().plot(kind='barh', color='chocolate')
plt.title('Min Stays in different room types listed on Airbnb', fontsize = 15)
plt.xlabel('Room types', fontsize = 14)
plt.ylabel('Min Stays', fontsize = 14 )
# Out:
# Text(0, 0.5, 'Min Stays')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# We choose this chart to show the minimum nights stays in different room types.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart gives us information about making facilities adequate and when respective room type going to available again for booking.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# By this chart we can derive business profit by making basic calculations like no of times respective room type can be available for booking in a month and accordingly we have to decide booking price considering expenses.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# Chart - visualization of each appartment using latitude and longitude
plt.figure(figsize = (15,8))
sns.scatterplot(x = airbnb_df["longitude"], y = airbnb_df["latitude"], hue = airbnb_df["neighbourhood_group"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

#check room type or room type
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(22, 6))
ax = axes.flatten()

sns.lineplot(data=airbnb_df, x='neighbourhood_group', y='availability_365', hue='room_type', ax=ax[0])
ax[0].set_title('Room Availability throughout Neighbourhood/Room Type')

sns.scatterplot(data=airbnb_df, x='price', y='number_of_reviews', hue='room_type', palette="GnBu_d",
        hue_order=['Private room', 'Shared room', 'Entire home/apt'], ax=ax[1])
ax[1].set_title('Price vs Number of Reviews')
sns.despine(fig, left=True)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

fig = plt.subplots(figsize=(10, 8))

sns.countplot(data=airbnb_df[airbnb_df['availability_365']  == 365], x='neighbourhood_group', hue='room_type', palette='GnBu_d')
plt.title('Property Available 365 days', fontsize=14)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
# Chart - average prefered price at every neighbourhood group as per type of room
avg_price_df = airbnb_df.groupby(['neighbourhood_group','room_type'])['price'].mean().unstack()
avg_price_df
# Out:
# room_type            Entire home/apt  Private room  Shared room
# neighbourhood_group
# Bronx                     127.506596     66.788344    59.800000
# Brooklyn                  178.327545     76.500099    50.527845
# Manhattan                 249.239109    116.776622    88.977083
# Queens                    147.050573     71.762456    69.020202
# Staten Island             173.846591     62.292553    57.444444

# %%
avg_price_df.plot.bar(figsize=(15,5),ylabel='Average Price calculated')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='Average Price calculated'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
#how the price is distributed over the type of room type
df_price = airbnb_df
sns.set_theme(style='whitegrid')
sns.boxplot(y='price',x='room_type',hue='room_type',palette='Set1',linewidth=3,fliersize=3,data=df_price)
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
figsize=(12,8)
sns.boxenplot(x='price',data=airbnb_df)
# Out:
# <Axes: xlabel='price'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
#Busiest_host
busiest_hosts = airbnb_df.groupby(['host_name','host_id','room_type'])['number_of_reviews'].max().reset_index()
busiest_hosts = busiest_hosts.sort_values(by='number_of_reviews', ascending=False).head(10)
busiest_hosts
# Out:
#       host_name   host_id        room_type  number_of_reviews
# 10279      Dona  47621202     Private room                629
# 17708        Jj   4734398     Private room                607
# 25566      Maya  37312959     Private room                543
# 6235      Carol   2369681     Private room                540
# 8947   Danielle  26432133     Private room                510
# 3950        Asa  12949460  Entire home/apt                488
# 37748     Wanda    792159     Private room                480
# 22499     Linda   2680820     Private room                474
# 8625       Dani     42273  Entire home/apt                467
# 2942     Angela  23591164     Private room                466

# %%
name = busiest_hosts['host_name']
reviews = busiest_hosts['number_of_reviews']

fig = plt.figure(figsize = (10, 5))
plt.bar(name, reviews, color ='chocolate', width = 0.4)
plt.xlabel("Name of the Host")
plt.ylabel("Number of Reviews")
plt.title("Busiest Hosts")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code

sns.distplot(airbnb_df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization 

# Correlation Heatmap visualization code
corr = airbnb_df.corr(method = 'kendall')
plt.figure(figsize= (15,10))
sns.heatmap(corr, annot =True)
airbnb_df.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code

sns.pairplot(airbnb_df, hue='room_type', x_vars='' kind='scatter', diag_kind= 'hist', )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.9/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
